# %%
pip install s3fs
# Out:
# Collecting s3fs
#   Downloading s3fs-2024.3.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting aiobotocore<3.0.0,>=2.5.4 (from s3fs)
#   Downloading aiobotocore-2.12.1-py3-none-any.whl.metadata (21 kB)
# Collecting fsspec==2024.3.1 (from s3fs)
#   Downloading fsspec-2024.3.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from s3fs)
#   Downloading aiohttp-3.9.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.4 kB)
# Collecting botocore<1.34.52,>=1.34.41 (from aiobotocore<3.0.0,>=2.5.4->s3fs)
#   Downloading botocore-1.34.51-py3-none-any.whl.metadata (5.7 kB)
# Collecting wrapt<2.0.0,>=1.10.10 (from aiobotocore<3.0.0,>=2.5.4->s3fs)
#   Downloading wrapt-1.16.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting aioitertools<1.0.0,>=0.5.1 (from aiobotocore<3.0.0,>=2.5.4->s3fs)
#   Downloading aioitertools-0.11.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (23.2.0)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs)
#   Downloading frozenlist-1.4.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs)
#   Downloading multidict-6.0.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs)
#   Downloading yarl-1.9.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (31 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from botocore<1.34.52,>=1.34.41->aiobotocore<3.0.0,>=2.5.4->s3fs)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from botocore<1.34.52,>=1.34.41->aiobotocore<3.0.0,>=2.5.4->s3fs) (2.9.0.post0)
# Collecting urllib3<2.1,>=1.25.4 (from botocore<1.34.52,>=1.34.41->aiobotocore<3.0.0,>=2.5.4->s3fs)
#   Downloading urllib3-2.0.7-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: idna>=2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (3.6)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.34.52,>=1.34.41->aiobotocore<3.0.0,>=2.5.4->s3fs) (1.16.0)
# Downloading s3fs-2024.3.1-py3-none-any.whl (29 kB)
# Downloading fsspec-2024.3.1-py3-none-any.whl (171 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.0/172.0 kB 2.8 MB/s eta 0:00:00 0:00:01
# Downloading aiobotocore-2.12.1-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.3/76.3 kB 3.9 MB/s eta 0:00:00
# Downloading aiohttp-3.9.3-cp312-cp312-macosx_11_0_arm64.whl (389 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.7/389.7 kB 4.4 MB/s eta 0:00:00a 0:00:01
# Downloading aioitertools-0.11.0-py3-none-any.whl (23 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading botocore-1.34.51-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 3.8 MB/s eta 0:00:0000:0100:01
# Downloading frozenlist-1.4.1-cp312-cp312-macosx_11_0_arm64.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.9/51.9 kB 3.2 MB/s eta 0:00:00
# Downloading multidict-6.0.5-cp312-cp312-macosx_11_0_arm64.whl (29 kB)
# Downloading wrapt-1.16.0-cp312-cp312-macosx_11_0_arm64.whl (38 kB)
# Downloading yarl-1.9.4-cp312-cp312-macosx_11_0_arm64.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.4/79.4 kB 6.3 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading urllib3-2.0.7-py3-none-any.whl (124 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 kB 10.4 MB/s eta 0:00:00
# Installing collected packages: wrapt, urllib3, multidict, jmespath, fsspec, frozenlist, aioitertools, yarl, botocore, aiosignal, aiohttp, aiobotocore, s3fs
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.1
#     Uninstalling urllib3-2.2.1:
#       Successfully uninstalled urllib3-2.2.1
# Successfully installed aiobotocore-2.12.1 aiohttp-3.9.3 aioitertools-0.11.0 aiosignal-1.3.1 botocore-1.34.51 frozenlist-1.4.1 fsspec-2024.3.1 jmespath-1.0.1 multidict-6.0.5 s3fs-2024.3.1 urllib3-2.0.7 wrapt-1.16.0 yarl-1.9.4
# Note: you may need to restart the kernel to use updated packages.

# %%
from kafka import KafkaConsumer
from time import sleep
from json import dumps,loads
import json
from s3fs import S3FileSystem

# %%
consumer = KafkaConsumer(
    'demo_testing_2',
     bootstrap_servers=['44.211.219.113:9092'], #add your IP here
    value_deserializer=lambda x: loads(x.decode('utf-8')))

# %%
for c in consumer:
    print(c.value)
# Out:
# {'surnasdasdame': 'parasdasdmar'}
# {'Index': 'IXIC', 'Date': '1990-11-23', 'Open': 348.799988, 'High': 349.700012, 'Low': 348.5, 'Close': 349.0, 'Adj Close': 349.0, 'Volume': 69420000.0, 'CloseUSD': 349.0}
# {'Index': 'IXIC', 'Date': '1971-08-09', 'Open': 103.18, 'High': 103.18, 'Low': 103.18, 'Close': 103.18, 'Adj Close': 103.18, 'Volume': 0.0, 'CloseUSD': 103.18}
# {'Index': 'IXIC', 'Date': '2016-08-24', 'Open': 5254.419922, 'High': 5262.990234, 'Low': 5205.640137, 'Close': 5217.689941, 'Adj Close': 5217.689941, 'Volume': 1714780000.0, 'CloseUSD': 5217.689941}
# {'Index': 'J203.JO', 'Date': '2020-02-18', 'Open': 58187.96094, 'High': 58187.96094, 'Low': 57483.60938, 'Close': 57714.66016, 'Adj Close': 57714.66016, 'Volume': 0.0, 'CloseUSD': 4040.026211200001}
# {'Index': 'IXIC', 'Date': '2021-02-01', 'Open': 13226.17969, 'High': 13431.45996, 'Low': 13132.46973, 'Close': 13403.38965, 'Adj Close': 13403.38965, 'Volume': 7014220000.0, 'CloseUSD': 13403.38965}
# {'Index': 'N225', 'Date': '2009-04-07', 'Open': 8838.660156, 'High': 8884.450195, 'Low': 8778.919922, 'Close': 8832.849609, 'Adj Close': 8832.849609, 'Volume': 150600000.0, 'CloseUSD': 88.32849609000002}
# {'Index': 'NYA', 'Date': '1973-06-29', 'Open': 579.859985, 'High': 579.859985, 'Low': 579.859985, 'Close': 579.859985, 'Adj Close': 579.859985, 'Volume': 0.0, 'CloseUSD': 579.859985}
# {'Index': 'N225', 'Date': '2008-06-10', 'Open': 14281.36035, 'High': 14308.88965, 'Low': 13983.55957, 'Close': 14021.16992, 'Adj Close': 14021.16992, 'Volume': 120700000.0, 'CloseUSD': 140.2116992}
# {'Index': 'IXIC', 'Date': '1981-06-03', 'Open': 218.889999, 'High': 218.889999, 'Low': 218.889999, 'Close': 218.889999, 'Adj Close': 218.889999, 'Volume': 0.0, 'CloseUSD': 218.889999}
# {'Index': 'NSEI', 'Date': '2014-03-04', 'Open': 6216.75, 'High': 6302.149902, 'Low': 6215.700195, 'Close': 6297.950195, 'Adj Close': 6297.950195, 'Volume': 166800.0, 'CloseUSD': 62.97950195000001}
# {'Index': '399001.SZ', 'Date': '2012-11-15', 'Open': 8231.110352, 'High': 8285.019531, 'Low': 8173.77002, 'Close': 8186.060059, 'Adj Close': 8185.968262, 'Volume': 32100.0, 'CloseUSD': 1309.76960944}
# {'Index': 'GSPTSE', 'Date': '2008-06-10', 'Open': 14897.5, 'High': 14960.79981, 'Low': 14660.59961, 'Close': 14736.2002, 'Adj Close': 14736.2002, 'Volume': 23697660000.0, 'CloseUSD': 12231.046165999998}
# {'Index': 'NYA', 'Date': '1993-04-02', 'Open': 2582.0, 'High': 2582.0, 'Low': 2582.0, 'Close': 2582.0, 'Adj Close': 2582.0, 'Volume': 0.0, 'CloseUSD': 2582.0}
# {'Index': 'N100', 'Date': '2006-08-11', 'Open': 858.780029, 'High': 863.0, 'Low': 855.700012, 'Close': 858.789978, 'Adj Close': 858.789978, 'Volume': 208385100.0, 'CloseUSD': 1047.72377316}
# {'Index': 'IXIC', 'Date': '2003-05-22', 'Open': 1493.390015, 'High': 1512.800049, 'Low': 1489.079956, 'Close': 1507.550049, 'Adj Close': 1507.550049, 'Volume': 1783870000.0, 'CloseUSD': 1507.550049}
# {'Index': '399001.SZ', 'Date': '2003-09-11', 'Open': 3152.139893, 'High': 3177.149902, 'Low': 3150.5, 'Close': 3160.820068, 'Adj Close': 3160.784668, 'Volume': 0.0, 'CloseUSD': 505.73121088}
# {'Index': '399001.SZ', 'Date': '1998-11-18', 'Open': 3364.919922, 'High': 3392.179932, 'Low': 3341.919922, 'Close': 3351.23999, 'Adj Close': 3351.202393, 'Volume': 0.0, 'CloseUSD': 536.1983984}
# {'Index': 'N225', 'Date': '2000-01-27', 'Open': 19125.61914, 'High': 19238.08008, 'Low': 18971.67969, 'Close': 19209.7207, 'Adj Close': 19209.7207, 'Volume': 0.0, 'CloseUSD': 192.09720700000003}
# {'Index': 'GDAXI', 'Date': '1991-12-11', 'Open': 1543.98999, 'High': 1543.98999, 'Low': 1543.98999, 'Close': 1543.98999, 'Adj Close': 1543.98999, 'Volume': 0.0, 'CloseUSD': 1883.6677878}
# {'Index': 'SSMI', 'Date': '2021-04-09', 'Open': 11206.84961, 'High': 11247.00977, 'Low': 11190.7002, 'Close': 11238.51953, 'Adj Close': 11238.51953, 'Volume': 59491200.0, 'CloseUSD': 12474.7566783}
# {'Index': 'N225', 'Date': '1990-03-19', 'Open': 32609.26953, 'High': 32721.43945, 'Low': 31198.21094, 'Close': 31263.24023, 'Adj Close': 31263.24023, 'Volume': 0.0, 'CloseUSD': 312.6324023}
# {'Index': 'NYA', 'Date': '1988-04-22', 'Open': 1554.660034, 'High': 1554.660034, 'Low': 1554.660034, 'Close': 1554.660034, 'Adj Close': 1554.660034, 'Volume': 0.0, 'CloseUSD': 1554.660034}
# {'Index': 'N225', 'Date': '2013-07-05', 'Open': 14150.84961, 'High': 14309.96973, 'Low': 14149.5, 'Close': 14309.96973, 'Adj Close': 14309.96973, 'Volume': 179400000.0, 'CloseUSD': 143.0996973}
# {'Index': '399001.SZ', 'Date': '2000-02-17', 'Open': 4564.589844, 'High': 4685.490234, 'Low': 4256.259766, 'Close': 4313.970215, 'Adj Close': 4313.921875, 'Volume': 0.0, 'CloseUSD': 690.2352344000001}
# {'Index': 'GSPTSE', 'Date': '2017-08-04', 'Open': 15247.40039, 'High': 15261.5, 'Low': 15198.5, 'Close': 15258.0, 'Adj Close': 15258.0, 'Volume': 15493490000.0, 'CloseUSD': 12664.14}
# {'Index': 'NSEI', 'Date': '2010-12-07', 'Open': 5995.049805, 'High': 6001.0, 'Low': 5939.700195, 'Close': 5976.549805, 'Adj Close': 5976.549805, 'Volume': 0.0, 'CloseUSD': 59.76549805}
# {'Index': 'IXIC', 'Date': '1972-01-20', 'Open': 117.32, 'High': 117.32, 'Low': 117.32, 'Close': 117.32, 'Adj Close': 117.32, 'Volume': 0.0, 'CloseUSD': 117.32}
# {'Index': '399001.SZ', 'Date': '2012-06-20', 'Open': 9877.19043, 'High': 9906.110352, 'Low': 9800.570313, 'Close': 9821.790039, 'Adj Close': 9821.679688, 'Volume': 38700.0, 'CloseUSD': 1571.48640624}
# {'Index': '000001.SS', 'Date': '2015-08-04', 'Open': 3621.85498, 'High': 3757.029053, 'Low': 3601.289063, 'Close': 3756.544922, 'Adj Close': 3756.544922, 'Volume': 362900.0, 'CloseUSD': 601.04718752}
# {'Index': 'N100', 'Date': '2019-06-04', 'Open': 1019.51001, 'High': 1032.119995, 'Low': 1016.780029, 'Close': 1030.01001, 'Adj Close': 1030.01001, 'Volume': 229551700.0, 'CloseUSD': 1256.6122122}
# {'Index': 'NYA', 'Date': '1984-11-29', 'Open': 999.530029, 'High': 999.530029, 'Low': 999.530029, 'Close': 999.530029, 'Adj Close': 999.530029, 'Volume': 0.0, 'CloseUSD': 999.530029}
# {'Index': 'N225', 'Date': '2010-07-16', 'Open': 9600.879883, 'High': 9636.839844, 'Low': 9392.209961, 'Close': 9408.360352, 'Adj Close': 9408.360352, 'Volume': 134000000.0, 'CloseUSD': 94.08360352}
# {'Index': 'IXIC', 'Date': '1974-01-31', 'Open': 94.93, 'High': 94.93, 'Low': 94.93, 'Close': 94.93, 'Adj Close': 94.93, 'Volume': 0.0, 'CloseUSD': 94.93}
# {'Index': 'GDAXI', 'Date': '2017-05-19', 'Open': 12612.29981, 'High': 12658.54981, 'Low': 12596.71973, 'Close': 12638.69043, 'Adj Close': 12638.69043, 'Volume': 118293100.0, 'CloseUSD': 15419.2023246}
# {'Index': 'N225', 'Date': '1976-01-21', 'Open': 4617.399902, 'High': 4617.399902, 'Low': 4617.399902, 'Close': 4617.399902, 'Adj Close': 4617.399902, 'Volume': 0.0, 'CloseUSD': 46.17399902}
# {'Index': 'NYA', 'Date': '1984-06-12', 'Open': 928.47998, 'High': 928.47998, 'Low': 928.47998, 'Close': 928.47998, 'Adj Close': 928.47998, 'Volume': 0.0, 'CloseUSD': 928.47998}
# {'Index': 'HSI', 'Date': '1995-06-16', 'Open': 9264.400391, 'High': 9367.700195, 'Low': 9260.700195, 'Close': 9314.0, 'Adj Close': 9314.0, 'Volume': 0.0, 'CloseUSD': 1210.82}
# {'Index': 'J203.JO', 'Date': '2013-03-28', 'Open': 39882.44141, 'High': 39943.75, 'Low': 39778.85938, 'Close': 39860.83984, 'Adj Close': 39860.83984, 'Volume': 0.0, 'CloseUSD': 2790.2587888000003}
# {'Index': 'TWII', 'Date': '2003-04-17', 'Open': 4593.890137, 'High': 4628.0, 'Low': 4564.52002, 'Close': 4566.660156, 'Adj Close': 4566.643066, 'Volume': 2350200.0, 'CloseUSD': 182.66640624}
# {'Index': 'HSI', 'Date': '1999-03-19', 'Open': 10817.05957, 'High': 11127.23047, 'Low': 10815.19043, 'Close': 11082.91992, 'Adj Close': 11082.91992, 'Volume': 0.0, 'CloseUSD': 1440.7795896}
# {'Index': 'SSMI', 'Date': '2017-09-06', 'Open': 8809.650391, 'High': 8874.25, 'Low': 8797.080078, 'Close': 8859.469727, 'Adj Close': 8859.469727, 'Volume': 52207700.0, 'CloseUSD': 9834.01139697}
# {'Index': 'N100', 'Date': '2017-05-31', 'Open': 1022.659973, 'High': 1027.969971, 'Low': 1019.880005, 'Close': 1019.98999, 'Adj Close': 1019.98999, 'Volume': 0.0, 'CloseUSD': 1244.3877878}
# {'Index': 'N225', 'Date': '1965-12-22', 'Open': 1373.790039, 'High': 1373.790039, 'Low': 1373.790039, 'Close': 1373.790039, 'Adj Close': 1373.790039, 'Volume': 0.0, 'CloseUSD': 13.73790039}
# {'Index': 'N225', 'Date': '2019-02-12', 'Open': 20442.55078, 'High': 20885.88086, 'Low': 20428.57031, 'Close': 20864.21094, 'Adj Close': 20864.21094, 'Volume': 84100000.0, 'CloseUSD': 208.6421094}
# {'Index': '399001.SZ', 'Date': '2011-05-10', 'Open': 12146.33008, 'High': 12216.94043, 'Low': 12102.79004, 'Close': 12216.94043, 'Adj Close': 12216.80371, 'Volume': 49000.0, 'CloseUSD': 1954.7104688}
# {'Index': 'HSI', 'Date': '2020-06-18', 'Open': 24386.31055, 'High': 24464.93945, 'Low': 24121.89063, 'Close': 24464.93945, 'Adj Close': 24464.93945, 'Volume': 1811327100.0, 'CloseUSD': 3180.4421285000003}
# {'Index': 'GSPTSE', 'Date': '2001-06-05', 'Open': 8333.400391, 'High': 8334.799805, 'Low': 8258.799805, 'Close': 8258.799805, 'Adj Close': 8258.799805, 'Volume': 12853620000.0, 'CloseUSD': 6854.80383815}
# {'Index': 'IXIC', 'Date': '1978-08-03', 'Open': 129.020004, 'High': 129.020004, 'Low': 129.020004, 'Close': 129.020004, 'Adj Close': 129.020004, 'Volume': 0.0, 'CloseUSD': 129.020004}
# {'Index': 'HSI', 'Date': '1993-09-30', 'Open': 7578.100098, 'High': 7678.600098, 'Low': 7578.100098, 'Close': 7676.200195, 'Adj Close': 7676.200195, 'Volume': 0.0, 'CloseUSD': 997.90602535}
# {'Index': 'NYA', 'Date': '2011-05-17', 'Open': 8336.589844, 'High': 8341.830078, 'Low': 8262.429688, 'Close': 8333.070313, 'Adj Close': 8333.070313, 'Volume': 4053970000.0, 'CloseUSD': 8333.070313}
# {'Index': 'GSPTSE', 'Date': '2004-10-29', 'Open': 8808.5, 'High': 8874.299805, 'Low': 8781.0, 'Close': 8871.0, 'Adj Close': 8871.0, 'Volume': 11469140000.0, 'CloseUSD': 7362.929999999999}
# {'Index': 'SSMI', 'Date': '2014-12-22', 'Open': 9011.240234, 'High': 9060.950195, 'Low': 9003.19043, 'Close': 9033.450195, 'Adj Close': 9033.450195, 'Volume': 33876600.0, 'CloseUSD': 10027.12971645}
# {'Index': 'HSI', 'Date': '1993-02-25', 'Open': 6176.899902, 'High': 6206.799805, 'Low': 6167.700195, 'Close': 6203.899902, 'Adj Close': 6203.899902, 'Volume': 0.0, 'CloseUSD': 806.5069872600001}
# {'Index': 'SSMI', 'Date': '1995-06-29', 'Open': 2838.699951, 'High': 2856.5, 'Low': 2837.899902, 'Close': 2845.600098, 'Adj Close': 2845.600098, 'Volume': 0.0, 'CloseUSD': 3158.61610878}
# {'Index': 'N225', 'Date': '1981-11-18', 'Open': 7667.310059, 'High': 7667.310059, 'Low': 7667.310059, 'Close': 7667.310059, 'Adj Close': 7667.310059, 'Volume': 0.0, 'CloseUSD': 76.67310059}
# {'Index': 'SSMI', 'Date': '2014-05-21', 'Open': 8625.530273, 'High': 8670.660156, 'Low': 8606.519531, 'Close': 8655.900391, 'Adj Close': 8655.900391, 'Volume': 33606400.0, 'CloseUSD': 9608.04943401}
# {'Index': 'NYA', 'Date': '2019-12-24', 'Open': 13902.95996, 'High': 13902.95996, 'Low': 13885.55957, 'Close': 13895.13965, 'Adj Close': 13895.13965, 'Volume': 1296540000.0, 'CloseUSD': 13895.13965}
# {'Index': 'N225', 'Date': '1996-06-07', 'Open': 21800.43945, 'High': 21800.43945, 'Low': 21672.42969, 'Close': 21751.81055, 'Adj Close': 21751.81055, 'Volume': 0.0, 'CloseUSD': 217.5181055}
# {'Index': 'N225', 'Date': '1997-10-29', 'Open': 16385.81055, 'High': 16920.08008, 'Low': 16385.81055, 'Close': 16857.03906, 'Adj Close': 16857.03906, 'Volume': 0.0, 'CloseUSD': 168.5703906}
# {'Index': 'NYA', 'Date': '2015-11-06', 'Open': 10525.65039, 'High': 10531.11035, 'Low': 10441.83984, 'Close': 10513.36035, 'Adj Close': 10513.36035, 'Volume': 4369020000.0, 'CloseUSD': 10513.36035}
# {'Index': 'N100', 'Date': '2000-01-25', 'Open': 943.880005, 'High': 943.880005, 'Low': 943.880005, 'Close': 943.880005, 'Adj Close': 943.880005, 'Volume': 0.0, 'CloseUSD': 1151.5336061}
# {'Index': 'GDAXI', 'Date': '2004-03-29', 'Open': 3828.040039, 'High': 3886.360107, 'Low': 3823.669922, 'Close': 3881.25, 'Adj Close': 3881.25, 'Volume': 73542500.0, 'CloseUSD': 4735.125}
# {'Index': 'NYA', 'Date': '2020-06-24', 'Open': 11956.29004, 'High': 11961.62012, 'Low': 11650.91016, 'Close': 11726.54004, 'Adj Close': 11726.54004, 'Volume': 5587200000.0, 'CloseUSD': 11726.54004}
# {'Index': '000001.SS', 'Date': '2011-10-13', 'Open': 2412.832031, 'High': 2439.639893, 'Low': 2406.281982, 'Close': 2438.790039, 'Adj Close': 2438.790039, 'Volume': 87800.0, 'CloseUSD': 390.20640624}
# {'Index': 'TWII', 'Date': '1997-08-01', 'Open': 9953.30957, 'High': 10102.76953, 'Low': 9942.339844, 'Close': 10001.55957, 'Adj Close': 10001.52148, 'Volume': 0.0, 'CloseUSD': 400.0623828}
# {'Index': 'NYA', 'Date': '1990-12-12', 'Open': 1905.910034, 'High': 1905.910034, 'Low': 1905.910034, 'Close': 1905.910034, 'Adj Close': 1905.910034, 'Volume': 0.0, 'CloseUSD': 1905.910034}
# {'Index': 'GDAXI', 'Date': '1992-07-07', 'Open': 1766.97998, 'High': 1766.97998, 'Low': 1766.97998, 'Close': 1766.97998, 'Adj Close': 1766.97998, 'Volume': 0.0, 'CloseUSD': 2155.7155756}
# {'Index': 'GSPTSE', 'Date': '1988-08-25', 'Open': 3263.199951, 'High': 3263.199951, 'Low': 3244.199951, 'Close': 3253.899902, 'Adj Close': 3245.636963, 'Volume': 20240000.0, 'CloseUSD': 2700.73691866}
# {'Index': 'SSMI', 'Date': '1994-07-21', 'Open': 2561.600098, 'High': 2581.600098, 'Low': 2545.800049, 'Close': 2579.399902, 'Adj Close': 2579.399902, 'Volume': 0.0, 'CloseUSD': 2863.1338912200004}
# {'Index': 'N225', 'Date': '1974-09-30', 'Open': 3950.0, 'High': 3950.0, 'Low': 3950.0, 'Close': 3950.0, 'Adj Close': 3950.0, 'Volume': 0.0, 'CloseUSD': 39.5}
# {'Index': 'NYA', 'Date': '2007-04-10', 'Open': 9429.25, 'High': 9472.80957, 'Low': 9429.25, 'Close': 9468.700195, 'Adj Close': 9468.700195, 'Volume': 2510110000.0, 'CloseUSD': 9468.700195}
# {'Index': 'N225', 'Date': '2015-06-01', 'Open': 20444.53906, 'High': 20595.41016, 'Low': 20410.26953, 'Close': 20569.86914, 'Adj Close': 20569.86914, 'Volume': 173400000.0, 'CloseUSD': 205.6986914}
# {'Index': 'GDAXI', 'Date': '1993-10-25', 'Open': 2061.179932, 'High': 2061.179932, 'Low': 2061.179932, 'Close': 2061.179932, 'Adj Close': 2061.179932, 'Volume': 0.0, 'CloseUSD': 2514.63951704}
# {'Index': 'N225', 'Date': '2021-03-04', 'Open': 29198.41992, 'High': 29277.18945, 'Low': 28711.03906, 'Close': 28930.10938, 'Adj Close': 28930.10938, 'Volume': 75200000.0, 'CloseUSD': 289.30109380000005}
# {'Index': 'TWII', 'Date': '2018-09-25', 'Open': 10959.55957, 'High': 11003.49023, 'Low': 10941.76953, 'Close': 10978.84961, 'Adj Close': 10978.84961, 'Volume': 1987200.0, 'CloseUSD': 439.1539844}
# {'Index': 'SSMI', 'Date': '2010-04-14', 'Open': 6921.589844, 'High': 6933.169922, 'Low': 6886.740234, 'Close': 6916.589844, 'Adj Close': 6916.589844, 'Volume': 53778000.0, 'CloseUSD': 7677.414726840001}
# {'Index': 'J203.JO', 'Date': '2017-09-18', 'Open': 55645.14844, 'High': 56209.57031, 'Low': 55645.14844, 'Close': 56050.10156, 'Adj Close': 56050.10156, 'Volume': 0.0, 'CloseUSD': 3923.5071092000007}
# {'Index': '000001.SS', 'Date': '2006-11-10', 'Open': 1896.928955, 'High': 1920.18396, 'Low': 1870.959961, 'Close': 1883.347046, 'Adj Close': 1883.347046, 'Volume': 62800.0, 'CloseUSD': 301.33552736}
# {'Index': 'SSMI', 'Date': '1993-08-12', 'Open': 2411.5, 'High': 2454.0, 'Low': 2409.699951, 'Close': 2450.5, 'Adj Close': 2450.5, 'Volume': 0.0, 'CloseUSD': 2720.0550000000003}
# {'Index': 'HSI', 'Date': '1987-07-23', 'Open': 3366.800049, 'High': 3366.800049, 'Low': 3366.800049, 'Close': 3366.800049, 'Adj Close': 3366.800049, 'Volume': 0.0, 'CloseUSD': 437.68400637}
# {'Index': 'GDAXI', 'Date': '2005-09-12', 'Open': 5028.490234, 'High': 5035.390137, 'Low': 4979.850098, 'Close': 4989.97998, 'Adj Close': 4989.97998, 'Volume': 95616200.0, 'CloseUSD': 6087.7755756}
# {'Index': 'TWII', 'Date': '2004-09-27', 'Open': 5872.02002, 'High': 5884.25, 'Low': 5832.370117, 'Close': 5849.220215, 'Adj Close': 5849.198242, 'Volume': 2714800.0, 'CloseUSD': 233.9688086}
# {'Index': 'GDAXI', 'Date': '2005-12-05', 'Open': 5303.919922, 'High': 5306.089844, 'Low': 5251.859863, 'Close': 5266.859863, 'Adj Close': 5266.859863, 'Volume': 100323500.0, 'CloseUSD': 6425.569032859999}
# {'Index': 'GDAXI', 'Date': '1997-05-15', 'Open': 3574.570068, 'High': 3577.300049, 'Low': 3550.620117, 'Close': 3564.850098, 'Adj Close': 3564.850098, 'Volume': 0.0, 'CloseUSD': 4349.11711956}
# {'Index': 'NYA', 'Date': '1982-08-05', 'Open': 639.080017, 'High': 639.080017, 'Low': 639.080017, 'Close': 639.080017, 'Adj Close': 639.080017, 'Volume': 0.0, 'CloseUSD': 639.080017}
# {'surnasdasdame': 'parasdasdmar'}
# {'Index': 'N100', 'Date': '2015-08-12', 'Open': 979.849976, 'High': 979.849976, 'Low': 954.23999, 'Close': 957.309998, 'Adj Close': 957.309998, 'Volume': 528682500.0, 'CloseUSD': 1167.91819756}
# {'Index': 'N225', 'Date': '2020-12-14', 'Open': 26659.5293, 'High': 26870.4707, 'Low': 26648.68945, 'Close': 26732.43945, 'Adj Close': 26732.43945, 'Volume': 60000000.0, 'CloseUSD': 267.32439450000004}
# {'Index': '000001.SS', 'Date': '2012-06-13', 'Open': 2289.707031, 'High': 2319.714111, 'Low': 2284.649902, 'Close': 2318.924072, 'Adj Close': 2318.924072, 'Volume': 78400.0, 'CloseUSD': 371.02785152}
# {'Index': 'NYA', 'Date': '2002-04-15', 'Open': 6173.470215, 'High': 6173.470215, 'Low': 6173.470215, 'Close': 6173.470215, 'Adj Close': 6173.470215, 'Volume': 1120400000.0, 'CloseUSD': 6173.470215}
# {'Index': 'N225', 'Date': '1976-03-12', 'Open': 4598.790039, 'High': 4598.790039, 'Low': 4598.790039, 'Close': 4598.790039, 'Adj Close': 4598.790039, 'Volume': 0.0, 'CloseUSD': 45.98790039000001}
# {'Index': 'GSPTSE', 'Date': '1997-08-08', 'Open': 6888.899902, 'High': 6910.700195, 'Low': 6859.100098, 'Close': 6895.200195, 'Adj Close': 6895.200195, 'Volume': 4844050000.0, 'CloseUSD': 5723.01616185}
# {'Index': 'NSEI', 'Date': '2011-03-03', 'Open': 5478.450195, 'High': 5570.75, 'Low': 5468.25, 'Close': 5536.200195, 'Adj Close': 5536.200195, 'Volume': 0.0, 'CloseUSD': 55.36200195000001}
# {'Index': 'GDAXI', 'Date': '2017-01-23', 'Open': 11545.96973, 'High': 11605.29004, 'Low': 11508.83008, 'Close': 11545.75, 'Adj Close': 11545.75, 'Volume': 77901600.0, 'CloseUSD': 14085.815}
# {'Index': 'N225', 'Date': '1986-02-19', 'Open': 13466.65039, 'High': 13466.65039, 'Low': 13466.65039, 'Close': 13466.65039, 'Adj Close': 13466.65039, 'Volume': 0.0, 'CloseUSD': 134.6665039}
# {'Index': 'TWII', 'Date': '1997-07-31', 'Open': 10111.83008, 'High': 10113.57031, 'Low': 10050.92969, 'Close': 10066.34961, 'Adj Close': 10066.31152, 'Volume': 0.0, 'CloseUSD': 402.6539844}
# {'Index': 'GSPTSE', 'Date': '1990-11-14', 'Open': 3125.899902, 'High': 3132.5, 'Low': 3119.5, 'Close': 3127.600098, 'Adj Close': 3119.657715, 'Volume': 20650000.0, 'CloseUSD': 2595.9080813399996}
# {'Index': 'NYA', 'Date': '2017-04-28', 'Open': 11579.30957, 'High': 11579.30957, 'Low': 11531.88965, 'Close': 11536.08008, 'Adj Close': 11536.08008, 'Volume': 3718270000.0, 'CloseUSD': 11536.08008}
# {'Index': 'NYA', 'Date': '2017-12-08', 'Open': 12605.0, 'High': 12643.12012, 'Low': 12587.61035, 'Close': 12643.05957, 'Adj Close': 12643.05957, 'Volume': 3106150000.0, 'CloseUSD': 12643.05957}
# {'Index': 'GSPTSE', 'Date': '1988-08-25', 'Open': 3263.199951, 'High': 3263.199951, 'Low': 3244.199951, 'Close': 3253.899902, 'Adj Close': 3245.636963, 'Volume': 20240000.0, 'CloseUSD': 2700.73691866}
# {'Index': 'GDAXI', 'Date': '2020-11-13', 'Open': 13036.96973, 'High': 13145.48047, 'Low': 13004.82031, 'Close': 13076.71973, 'Adj Close': 13076.71973, 'Volume': 79173300.0, 'CloseUSD': 15953.5980706}
# {'Index': 'NYA', 'Date': '1970-08-11', 'Open': 435.0, 'High': 435.0, 'Low': 435.0, 'Close': 435.0, 'Adj Close': 435.0, 'Volume': 0.0, 'CloseUSD': 435.0}
# {'Index': 'N100', 'Date': '2006-08-21', 'Open': 880.859985, 'High': 882.01001, 'Low': 876.609985, 'Close': 878.659973, 'Adj Close': 878.659973, 'Volume': 156025900.0, 'CloseUSD': 1071.96516706}
# {'Index': 'GSPTSE', 'Date': '1998-04-09', 'Open': 7597.100098, 'High': 7621.0, 'Low': 7591.399902, 'Close': 7620.600098, 'Adj Close': 7620.600098, 'Volume': 7307330000.0, 'CloseUSD': 6325.098081339999}
# {'Index': 'N100', 'Date': '2012-12-05', 'Open': 676.409973, 'High': 676.880005, 'Low': 672.190002, 'Close': 674.590027, 'Adj Close': 674.590027, 'Volume': 190071600.0, 'CloseUSD': 822.9998329399999}
# {'Index': 'N225', 'Date': '2020-04-24', 'Open': 19331.85938, 'High': 19352.24023, 'Low': 19175.38086, 'Close': 19262.0, 'Adj Close': 19262.0, 'Volume': 84700000.0, 'CloseUSD': 192.62}
# {'Index': 'GSPTSE', 'Date': '1985-10-25', 'Open': 2644.300049, 'High': 2644.300049, 'Low': 2632.899902, 'Close': 2632.899902, 'Adj Close': 2626.213623, 'Volume': 10910000.0, 'CloseUSD': 2185.30691866}
# {'Index': 'NSEI', 'Date': '2012-01-30', 'Open': 5163.549805, 'High': 5166.149902, 'Low': 5076.700195, 'Close': 5087.299805, 'Adj Close': 5087.299805, 'Volume': 0.0, 'CloseUSD': 50.87299805}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 for c in consumer:
#       2     print(c.value)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/kafka/consumer/group.py:1203, in KafkaConsumer.__next__(self)
#    1201     return self.next_v1()
#    1202 else:
# -> 1203     return self.next_v2()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/kafka/consumer/group.py:1211, in KafkaConsumer.next_v2(self)
#    1209     self._iterator = self._message_generator_v2()
#    1210 try:
# -> 1211     return next(self._iterator)
#    1212 except StopIteration:
#    1213     self._iterator = None
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/kafka/consumer/group.py:1126, in KafkaConsumer._message_generator_v2(self)
#    1124 def _message_generator_v2(self):
#    1125     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1126     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1127     for tp, records in record_map.items():
#    1128         # Generators are stateful, and it is possible that the tp / records
#    1129         # here may become stale during iteration -- i.e., we seek to a
#    1130         # different offset, pause consumption, or lose assignment.
#    1131         for record in records:
#    1132             # is_fetchable(tp) should handle assignment changes and offset
#    1133             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1134             # outer function destroying the existing iterator/generator
#    1135             # via self._iterator = None
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/kafka/consumer/group.py:663, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     661 remaining = timeout_ms
#     662 while not self._closed:
# --> 663     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     664     if records:
#     665         return records
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/kafka/consumer/group.py:712, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     709     self._client.poll(timeout_ms=0)
#     711 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 712 self._client.poll(timeout_ms=timeout_ms)
#     713 # after the long poll, we should check whether the group needs to rebalance
#     714 # prior to returning data so that the group can stabilize faster
#     715 if self._coordinator.need_rejoin():
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/kafka/client_async.py:590, in KafkaClient.poll(self, timeout_ms, future)
#     587             timeout = min(timeout, self.config['retry_backoff_ms'])
#     588         timeout = max(0, timeout)  # avoid negative timeouts
# --> 590     self._poll(timeout / 1000)
#     592 # called without the lock to avoid deadlock potential
#     593 # if handlers need to acquire locks
#     594 responses.extend(self._fire_pending_completed_requests())
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/kafka/client_async.py:622, in KafkaClient._poll(self, timeout)
#     619 self._register_send_sockets()
#     621 start_select = time.time()
# --> 622 ready = self._selector.select(timeout)
#     623 end_select = time.time()
#     624 if self._sensors:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/selectors.py:566, in KqueueSelector.select(self, timeout)
#     564 ready = []
#     565 try:
# --> 566     kev_list = self._selector.control(None, max_ev, timeout)
#     567 except InterruptedError:
#     568     return ready
#
# KeyboardInterrupt:

# %%
s3 = S3FileSystem()

# %%
for count, i in enumerate(consumer):
    with s3.open("s3://aws-first-project-kafka/stock_market_{}.json".format(count), 'w') as file:
        json.dump(i.value, file)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 for count, i in enumerate(consumer):
#       2     with s3.open("s3://aws-first-project-kafka/stock_market_{}.json".format(count), 'w') as file:
#       3         json.dump(i.value, file)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/kafka/consumer/group.py:1203, in KafkaConsumer.__next__(self)
#    1201     return self.next_v1()
#    1202 else:
# -> 1203     return self.next_v2()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/kafka/consumer/group.py:1211, in KafkaConsumer.next_v2(self)
#    1209     self._iterator = self._message_generator_v2()
#    1210 try:
# -> 1211     return next(self._iterator)
#    1212 except StopIteration:
#    1213     self._iterator = None
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/kafka/consumer/group.py:1126, in KafkaConsumer._message_generator_v2(self)
#    1124 def _message_generator_v2(self):
#    1125     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1126     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1127     for tp, records in record_map.items():
#    1128         # Generators are stateful, and it is possible that the tp / records
#    1129         # here may become stale during iteration -- i.e., we seek to a
#    1130         # different offset, pause consumption, or lose assignment.
#    1131         for record in records:
#    1132             # is_fetchable(tp) should handle assignment changes and offset
#    1133             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1134             # outer function destroying the existing iterator/generator
#    1135             # via self._iterator = None
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/kafka/consumer/group.py:663, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     661 remaining = timeout_ms
#     662 while not self._closed:
# --> 663     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     664     if records:
#     665         return records
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/kafka/consumer/group.py:712, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     709     self._client.poll(timeout_ms=0)
#     711 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 712 self._client.poll(timeout_ms=timeout_ms)
#     713 # after the long poll, we should check whether the group needs to rebalance
#     714 # prior to returning data so that the group can stabilize faster
#     715 if self._coordinator.need_rejoin():
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/kafka/client_async.py:590, in KafkaClient.poll(self, timeout_ms, future)
#     587             timeout = min(timeout, self.config['retry_backoff_ms'])
#     588         timeout = max(0, timeout)  # avoid negative timeouts
# --> 590     self._poll(timeout / 1000)
#     592 # called without the lock to avoid deadlock potential
#     593 # if handlers need to acquire locks
#     594 responses.extend(self._fire_pending_completed_requests())
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/kafka/client_async.py:622, in KafkaClient._poll(self, timeout)
#     619 self._register_send_sockets()
#     621 start_select = time.time()
# --> 622 ready = self._selector.select(timeout)
#     623 end_select = time.time()
#     624 if self._sensors:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/selectors.py:566, in KqueueSelector.select(self, timeout)
#     564 ready = []
#     565 try:
# --> 566     kev_list = self._selector.control(None, max_ev, timeout)
#     567 except InterruptedError:
#     568     return ready
#
# KeyboardInterrupt:
